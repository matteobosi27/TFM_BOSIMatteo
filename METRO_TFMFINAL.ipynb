# %%
import os
import pandas as pd

df = pd.DataFrame()

df = pd.read_csv("XXX.csv")
    
df = df.drop('Unnamed: 0', axis=1)

# %%
import matplotlib.pyplot as plt
from matplotlib.font_manager import FontProperties

df_grouped = df.groupby('Estacion').mean()
df_grouped = df_grouped.transpose()

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

plt.figure(figsize=(12, 8))

font = FontProperties(family='Calibri', size=12)

for station in df_grouped.columns:
    color = station_colors.get(station, 'gray')
    plt.plot(df_grouped.index, df_grouped[station], label=station, color=color)

plt.xlabel('Fecha', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de entradas por día entre el 15 de abril y el 15 de mayo', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='center left')

plt.xticks(rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerospordia_todas_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_8mayo = df[['Estacion', 'Media Hora', '08/05/2022']].copy()

horas_dia = pd.date_range('2022-05-08 05:00', '2022-05-09 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

for estacion in df_8mayo['Estacion'].unique():
    valores_estacion = df_8mayo.loc[df_8mayo['Estacion'] == estacion, '08/05/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de entradas por estación y hora (8 de mayo de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='upper left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_8mayo_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_17abril = df[['Estacion', 'Media Hora', '17/04/2022']].copy()

horas_dia = pd.date_range('2022-04-17 05:00', '2022-04-18 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

for estacion in df_17abril['Estacion'].unique():
    valores_estacion = df_17abril.loc[df_17abril['Estacion'] == estacion, '17/04/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de entradas por estación y hora (17 de abril de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='center left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_17abril_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_15mayo = df[['Estacion', 'Media Hora', '15/05/2022']].copy()

horas_dia = pd.date_range('2022-05-15 05:00', '2022-05-16 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

for estacion in df_15mayo['Estacion'].unique():
    valores_estacion = df_15mayo.loc[df_15mayo['Estacion'] == estacion, '15/05/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de entradas por estación y hora (15 de mayo de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='center left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_15mayo_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_20abril = df[['Estacion', 'Media Hora', '20/04/2022']].copy()

horas_dia = pd.date_range('2022-04-20 05:00', '2022-04-21 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

for estacion in df_20abril['Estacion'].unique():
    valores_estacion = df_20abril.loc[df_20abril['Estacion'] == estacion, '20/04/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de viajeros por estación y hora (20 de abril de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='upper left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_20abril_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_04mayo = df[['Estacion', 'Media Hora', '04/05/2022']].copy()

horas_dia = pd.date_range('2022-05-04 05:00', '2022-05-05 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

fo|r estacion in df_04mayo['Estacion'].unique():
    valores_estacion = df_04mayo.loc[df_04mayo['Estacion'] == estacion, '04/05/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de viajeros por estación y hora (04 de mayo de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='upper left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_04mayo_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_11mayo = df[['Estacion', 'Media Hora', '11/05/2022']].copy()

horas_dia = pd.date_range('2022-05-11 05:00', '2022-05-12 01:00', freq='H')

plt.figure(figsize=(12, 8))

station_colors = {
    'Callao': '#D1CB6A',
    'Legazpi': '#775CD6',
    'San_Fermin_Orcasur': '#357F8C',
    'Sol': '#E75279',
    'Villaverde_Alto': '#58FB8E',
    'Villaverde_Bajo_Cruce': '#85603F',
}

font = FontProperties(family='Calibri', size=12)
legend_font = FontProperties(family='Calibri', size=10)

for estacion in df_11mayo['Estacion'].unique():
    valores_estacion = df_11mayo.loc[df_11mayo['Estacion'] == estacion, '11/05/2022']
    color = station_colors.get(estacion, 'gray')
    plt.plot(horas_dia, valores_estacion, label=estacion, color=color)

plt.xlabel('Hora', fontname='Calibri', labelpad=15)
plt.ylabel('Número de viajeros', fontname='Calibri', labelpad=15)
plt.title('Número de viajeros por estación y hora (11 de mayo de 2022)', fontname='Calibri', pad=20)

plt.legend(prop=legend_font, loc='upper left')

horas_labels = [hora.strftime('%H:%M') for hora in horas_dia]

plt.xticks(horas_dia, horas_labels, rotation='vertical', fontname='Calibri')

plt.savefig('numeroviajerosporestacion_11mayo_metro', dpi=300, bbox_inches='tight')

plt.show()

# %%
df = pd.DataFrame()

df = pd.read_csv("datos_Metro_horarios.csv")
    
df = df.drop('Unnamed: 0', axis=1)

df_nuevo = pd.DataFrame(df.set_index(["Estacion", "Media Hora"]).stack())
df_nuevo.reset_index(inplace=True)
df_nuevo.columns = ["Estacion", "Hora", "Fecha", "Viajeros"]

df_nuevo['Fecha'] = pd.to_datetime(df_nuevo['Fecha'], dayfirst=True)

# %%
import seaborn as sns

df_nuevo['Fecha'] = pd.to_datetime(df_nuevo['Fecha'], dayfirst=True)

df_filtered = df_nuevo

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia diaria de las líneas, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrenciadiaria_base1_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '10:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 10:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '11:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 11:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '18:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 18:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '19:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 19:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '20:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 20:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '21:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 21:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '22:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 22:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '23:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 23:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
df_filtered = df_nuevo[(df_nuevo['Hora'] == '0:00')]

avg_viajeros = df_filtered.groupby(['Estacion', 'Fecha'])['Viajeros'].mean().unstack()

normalized_values = avg_viajeros.apply(lambda x: (x - x.min()) / (x.max() - x.min()), axis=1)

plt.figure(figsize=(12, 6))

sns.heatmap(normalized_values, cmap='YlGnBu', cbar=False)

for i, line_name in enumerate(normalized_values.index):
    for j, value in enumerate(normalized_values.loc[line_name]):
        plt.text(j + 0.5, i + 0.5, f'{value:.2f}', ha='center', va='center', rotation='vertical', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Concurrencia de las líneas a las 00:00, con base 1 el día de mayor concurrencia', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('concurrencia_10_bus', dpi=300, bbox_inches='tight')

plt.show()

# %%
from matplotlib.font_manager import FontProperties

df_nuevo.sort_values(['Estacion', 'Fecha', 'Hora'], inplace=True)

df_max_viajeros = df_nuevo.groupby(['Estacion', 'Fecha'])['Viajeros'].agg(['max', 'idxmax']).reset_index()

df_max_viajeros['Hora_Max_Viajeros'] = df_max_viajeros['idxmax'].apply(lambda x: df_nuevo.loc[x, 'Hora'])

pivot_table = df_max_viajeros.pivot(index='Estacion', columns='Fecha', values='Hora_Max_Viajeros')

plt.figure(figsize=(10, 6))

sns.heatmap(pivot_table, cmap='viridis', annot=False, fmt=".2f", cbar=True)

x_coords = range(len(pivot_table.columns))
y_coords = range(len(pivot_table.index))

for i, y in enumerate(y_coords):
    for j, x in enumerate(x_coords):
        plt.text(x + 0.5, y + 0.5, pivot_table.iloc[y, x], ha='center', va='center', rotation='vertical', color='white', fontname='Calibri')

plt.xlabel('Día', labelpad=10, fontname='Calibri')
plt.ylabel('Línea', labelpad=10, fontname='Calibri')
plt.title('Hora del máximo número de viajeros por línea y día', pad=20, fontname='Calibri')

date_objects = df_filtered['Fecha'].dt.date.unique()  

plt.xticks(range(len(date_objects)), [date.strftime('%m-%d') for date in date_objects], fontname='Calibri')  
plt.yticks(fontname='Calibri')

plt.savefig('horamaximoviajeros_bus', dpi=300, bbox_inches='tight')

plt.show()
